# %%
import tensorflow as tf
import pandas as pd
import xarray as xr
import pickle
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, mean_absolute_error,confusion_matrix, classification_report, roc_curve, auc
import seaborn as sns
from sklearn.utils import resample
from sklearn.neural_network import MLPClassifier
import keras
#from tensorflow.keras.wrappers.scikit_learn import KerasClassifier




# Deep learning model
from tensorflow.keras.layers import Input, Dense, Reshape, Concatenate, Embedding, Dropout, Flatten
from tensorflow.keras.models import Model, load_model, Sequential
from keras.callbacks import EarlyStopping
from sklearn.model_selection import GridSearchCV
from keras.regularizers import l1
from keras.layers import BatchNormalization
from scikeras.wrappers import KerasClassifier, KerasRegressor
import keras.backend as K
# Out:
# 2024-05-09 18:56:40.186393: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-09 18:56:40.227986: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-09 18:56:40.228033: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-09 18:56:40.229206: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-09 18:56:40.235775: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-09 18:56:40.236214: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-09 18:56:41.281133: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
parameter_data = pd.read_csv('../02_machine_learning/parameter_data_lead_time_also_FZ.csv')
parameter_data.drop(columns=['airport_id'], inplace=True)
parameter_data['airport_id'] = pd.factorize(parameter_data['airport'])[0]

# %%
# Train test split
X_train, X_test = train_test_split(parameter_data, test_size = 0.2, random_state=9)

# %% [markdown]
# ### Downsampling the occurrences of FALSE for contain_FZ

# %%
downsampling_percentage = 0.033

fz_majority = X_train[X_train['contain_FZ'] == False]
fz_minority = X_train[X_train['contain_FZ'] == True]

print(f'Size of minority: {fz_majority.shape}')
print(f'Size of minority: {fz_minority.shape}')

majority_size = int(len(fz_majority) * downsampling_percentage)

# Downsample the majority class to match the minority class
downsampled_majority = resample(fz_majority, replace=False, n_samples=majority_size, random_state=42)
print(f'Size of downsampled majority: {downsampled_majority.shape}')

# Combine the downsampled majority class with the original minority class
downsampled_X_train = pd.concat([downsampled_majority, fz_minority])
# Out:
# Size of minority: (440007, 127)
# Size of minority: (4243, 127)
# Size of downsampled majority: (14520, 127)

# %%
X_train_downsampled = downsampled_X_train.drop(['contain_FZ'], axis=1)
y_train = downsampled_X_train['contain_FZ']
y_test = X_test['contain_FZ']
X_test = X_test.drop(['contain_FZ'], axis=1)

# %% [markdown]
# ## F1-score

# %%
def f1_score_calc(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# ## Standardize features

# %%
data_params = ['air_temperature_0m', 'air_temperature_2m', 'relative_humidity_2m', 'x_wind_10m', 'y_wind_10m', 'fog_area_fraction', 'surface_air_pressure', 
               'air_pressure_at_sea_level', 'precipitation_amount_calculated',
              'air_temperature_pl_850', 'x_wind_pl_850', 'y_wind_pl_850', 'air_temperature_pl_925', 'x_wind_pl_925', 'y_wind_pl_925',
              'liquid_water_content_of_surface_snow']

# %%
scaler = StandardScaler()

X_train_downsampled[data_params] = scaler.fit_transform(X_train_downsampled[data_params])
X_test[data_params] = scaler.transform(X_test[data_params])

# %% [markdown]
# ## Embedding layer for airport id

# %%
num_airports = len(parameter_data['airport_id'].unique())
print(f'Number of airports: {num_airports}')
input_aid = Input(shape=(1,))
output_dim = 20

embedding_layer = Embedding(input_dim=num_airports, output_dim=output_dim, name="embedding_airport")(input_aid)
flatten_airports = Flatten()(embedding_layer)

emb_cat = Reshape(target_shape=(output_dim,))(flatten_airports)
# Out:
# Number of airports: 54

# %% [markdown]
# ## Model: ANN

# %%
l1_lambda = 0.002

param_features_dim = Input(shape=(16,))

# Concatenate embedded categorical airport feature with param features
concat = Concatenate()([emb_cat, param_features_dim])

dense_layer_1 = Dense(units=64, kernel_initializer='he_uniform', kernel_regularizer=l1(l1_lambda), activation='relu')(concat)
batch_norm_1 = BatchNormalization()(dense_layer_1)
#dropout_1 = Dropout(0.2)(batch_norm_1)

dense_layer_2 = Dense(units=64, kernel_initializer='he_uniform', kernel_regularizer=l1(l1_lambda),activation='relu')(batch_norm_1)
batch_norm_2 = BatchNormalization()(dense_layer_2)

dense_layer_3 = Dense(units=64, kernel_initializer='he_uniform', kernel_regularizer=l1(l1_lambda),activation='relu')(batch_norm_2)
batch_norm_3 = BatchNormalization()(dense_layer_3)


#dense_layer_4 = Dense(units=64, kernel_initializer='he_uniform', kernel_regularizer=l1(l1_lambda),activation='relu')(batch_norm_3)
#batch_norm_4 = BatchNormalization()(dense_layer_4)

#dense_layer_4 = Dense(units=32, kernel_initializer='he_uniform', kernel_regularizer=l1(l1_lambda),activation='relu')(dense_layer_3)

#batch_norm_2 = BatchNormalization()(dense_layer_3)

#dense_layer_3 = Dense(units=64, kernel_initializer='he_uniform', kernel_regularizer=l1(l1_lambda), activation='relu')(batch_norm_2)
#batch_norm_3 = BatchNormalization()(dense_layer_3)

#dense_layer_4 = Dense(units=32, kernel_initializer='he_uniform', kernel_regularizer=l1(l1_lambda), activation='relu')(batch_norm_3)
#batch_norm_4 = BatchNormalization()(dense_layer_4)

# Output Layer
output_layer = Dense(units=1, activation='sigmoid')(batch_norm_3)
model = Model(inputs=[input_aid, param_features_dim], outputs=output_layer)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 1)]                  0         []
#
#  embedding_airport (Embeddi  (None, 1, 20)                1080      ['input_1[0][0]']
#  ng)
#
#  flatten (Flatten)           (None, 20)                   0         ['embedding_airport[0][0]']
#
#  reshape (Reshape)           (None, 20)                   0         ['flatten[0][0]']
#
#  input_2 (InputLayer)        [(None, 16)]                 0         []
#
#  concatenate (Concatenate)   (None, 36)                   0         ['reshape[0][0]',
#                                                                      'input_2[0][0]']
#
#  dense (Dense)               (None, 64)                   2368      ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 64)                   256       ['dense[0][0]']
#  Normalization)
#
#  dense_1 (Dense)             (None, 64)                   4160      ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 64)                   256       ['dense_1[0][0]']
#  chNormalization)
#
#  dense_2 (Dense)             (None, 64)                   4160      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 64)                   256       ['dense_2[0][0]']
#  chNormalization)
#
#  dense_3 (Dense)             (None, 1)                    65        ['batch_normalization_2[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 12601 (49.22 KB)
# Trainable params: 12217 (47.72 KB)
# Non-trainable params: 384 (1.50 KB)
# __________________________________________________________________________________________________

# %%
# Compile the model
ml_optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=ml_optimizer, metrics=[f1_score_calc])

# %%
# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = model.fit([X_train_downsampled['airport_id'], X_train_downsampled[data_params]], y_train, epochs=100, batch_size=32, shuffle=True, validation_split=0.2, verbose=1, callbacks=early_stopping)
# Out:
# Epoch 1/100
# /home/tonjek/.local/lib/python3.9/site-packages/keras/src/engine/data_adapter.py:1808: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 470/470 [==============================] - 2s 2ms/step - loss: 2.2179 - f1_score_calc: 0.0249 - val_loss: 3.9767 - val_f1_score_calc: 0.0592
# Epoch 2/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.8070 - f1_score_calc: 0.0265 - val_loss: 3.7733 - val_f1_score_calc: 0.0870
# Epoch 3/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.4373 - f1_score_calc: 0.0152 - val_loss: 3.5496 - val_f1_score_calc: 0.0123
# Epoch 4/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.2907 - f1_score_calc: 0.0160 - val_loss: 3.0595 - val_f1_score_calc: 0.0208
# Epoch 5/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.2276 - f1_score_calc: 0.0142 - val_loss: 2.8636 - val_f1_score_calc: 0.0542
# Epoch 6/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1945 - f1_score_calc: 0.0021 - val_loss: 3.3606 - val_f1_score_calc: 0.1037
# Epoch 7/100
# 470/470 [==============================] - 1s 2ms/step - loss: 0.1719 - f1_score_calc: 0.0121 - val_loss: 2.9435 - val_f1_score_calc: 0.0741
# Epoch 8/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1579 - f1_score_calc: 0.0406 - val_loss: 2.4004 - val_f1_score_calc: 0.0982
# Epoch 9/100
# 470/470 [==============================] - 1s 2ms/step - loss: 0.1381 - f1_score_calc: 0.0292 - val_loss: 2.2957 - val_f1_score_calc: 0.1576
# Epoch 10/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1313 - f1_score_calc: 0.0252 - val_loss: 2.1804 - val_f1_score_calc: 0.2642
# Epoch 11/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1304 - f1_score_calc: 0.0407 - val_loss: 2.6999 - val_f1_score_calc: 0.2090
# Epoch 12/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1267 - f1_score_calc: 0.0416 - val_loss: 2.5868 - val_f1_score_calc: 0.0485
# Epoch 13/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1275 - f1_score_calc: 0.0276 - val_loss: 2.3077 - val_f1_score_calc: 0.1151
# Epoch 14/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1245 - f1_score_calc: 0.0305 - val_loss: 2.3591 - val_f1_score_calc: 0.0215
# Epoch 15/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1248 - f1_score_calc: 0.0379 - val_loss: 2.5092 - val_f1_score_calc: 0.0689
# Epoch 16/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1216 - f1_score_calc: 0.0351 - val_loss: 2.1790 - val_f1_score_calc: 0.1588
# Epoch 17/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1202 - f1_score_calc: 0.0414 - val_loss: 2.1433 - val_f1_score_calc: 0.1976
# Epoch 18/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1184 - f1_score_calc: 0.0227 - val_loss: 2.3718 - val_f1_score_calc: 0.0183
# Epoch 19/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1174 - f1_score_calc: 0.0294 - val_loss: 2.4610 - val_f1_score_calc: 0.1542
# Epoch 20/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1162 - f1_score_calc: 0.0352 - val_loss: 2.1630 - val_f1_score_calc: 0.2012
# Epoch 21/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1155 - f1_score_calc: 0.0323 - val_loss: 2.4805 - val_f1_score_calc: 0.1364
# Epoch 22/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1150 - f1_score_calc: 0.0461 - val_loss: 2.3668 - val_f1_score_calc: 0.1092
# Epoch 23/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1159 - f1_score_calc: 0.0228 - val_loss: 2.2131 - val_f1_score_calc: 0.1061
# Epoch 24/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1162 - f1_score_calc: 0.0360 - val_loss: 2.5720 - val_f1_score_calc: 0.0868
# Epoch 25/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1151 - f1_score_calc: 0.0305 - val_loss: 2.3334 - val_f1_score_calc: 0.1413
# Epoch 26/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1144 - f1_score_calc: 0.0600 - val_loss: 2.1253 - val_f1_score_calc: 0.2475
# Epoch 27/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1150 - f1_score_calc: 0.0575 - val_loss: 2.1061 - val_f1_score_calc: 0.1899
# Epoch 28/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1152 - f1_score_calc: 0.0544 - val_loss: 2.4833 - val_f1_score_calc: 0.0484
# Epoch 29/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1139 - f1_score_calc: 0.0411 - val_loss: 2.4194 - val_f1_score_calc: 0.0819
# Epoch 30/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1155 - f1_score_calc: 0.0443 - val_loss: 1.7914 - val_f1_score_calc: 0.2792
# Epoch 31/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1149 - f1_score_calc: 0.0380 - val_loss: 2.4097 - val_f1_score_calc: 0.2463
# Epoch 32/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1150 - f1_score_calc: 0.0373 - val_loss: 2.2248 - val_f1_score_calc: 0.1865
# Epoch 33/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1132 - f1_score_calc: 0.0540 - val_loss: 2.3405 - val_f1_score_calc: 0.1767
# Epoch 34/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1141 - f1_score_calc: 0.0597 - val_loss: 2.3296 - val_f1_score_calc: 0.1105
# Epoch 35/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1142 - f1_score_calc: 0.0354 - val_loss: 2.7863 - val_f1_score_calc: 0.0570
# Epoch 36/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1165 - f1_score_calc: 0.0556 - val_loss: 2.0616 - val_f1_score_calc: 0.2233
# Epoch 37/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1151 - f1_score_calc: 0.0491 - val_loss: 2.2886 - val_f1_score_calc: 0.0720
# Epoch 38/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1149 - f1_score_calc: 0.0443 - val_loss: 2.2320 - val_f1_score_calc: 0.1984
# Epoch 39/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1122 - f1_score_calc: 0.0565 - val_loss: 2.2001 - val_f1_score_calc: 0.2924
# Epoch 40/100
# 470/470 [==============================] - 1s 1ms/step - loss: 0.1126 - f1_score_calc: 0.0443 - val_loss: 1.8254 - val_f1_score_calc: 0.4073

# %%
history = pd.DataFrame(history.history)

cmap_loss_val = sns.color_palette('viridis', 2)



plt.plot(history.loc[:, ['loss']], color=cmap_loss_val[0], label='Training loss')
plt.plot(history.loc[:, ['val_loss']], color=cmap_loss_val[1], label='Validation loss')
plt.title('Training and Validation loss: Model t0+0, 1% of Majority Class')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc="best")

plt.savefig('training_validation_loss_t0+0.png')
plt.show()

# %% [markdown]
# ## Prediction

# %%
# Make predictions
y_pred = model.predict([X_test['airport_id'], X_test[data_params]])
# Out:
# 3471/3471 [==============================] - 2s 587us/step

# %%
y_pred_val = (y_pred > 0.4)
print(classification_report(y_test, y_pred_val))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99    109993
#         True       0.16      0.30      0.21      1070
#
#     accuracy                           0.98    111063
#    macro avg       0.58      0.64      0.60    111063
# weighted avg       0.99      0.98      0.98    111063

# %%
conf_matrix = confusion_matrix(y_test, y_pred_val)

# %%
conf_matrix
# Out:
# array([[108362,   1631],
#        [   753,    317]])

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test, y_pred_val)

# %%
f1
# Out:
# 0.2100728959575878

# %% [markdown]
# ## ROC AUC

# %%
# Calculate fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Calculate AUC
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve: Y_PRED > 0.8')
plt.legend(loc="lower right")
#plt.savefig('rocauc_instantaneous_0.8.png')
plt.show()

# %%
# Save y_pred as numpy
#np.save('y_pred_instantanous_2.npy', y_pred)

# Save corresponding y_test
#np.save('y_test_instantanous_2.npy', y_test)

# %% [markdown]
# # Analyzation of data
# The code from here and forward is for analyzation purposes.

# %%
y_pred = y_pred.flatten()

# %%
comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred, 'Time': X_test['time'], 'Metar': X_test['metar']})

# %%
comparison_df.to_csv('comparison.csv', index=False)

# %%
pd.set_option('display.max_colwidth', 3000)

# %%
comparison_df[comparison_df['Predicted'] > 0.95].head(50)
# Out:
#         Actual  Predicted                 Time  \
# 326069    True   0.987683  2022-11-19 14:00:00
# 201927   False   0.960360  2022-04-26 13:00:00
# 384220   False   0.985071  2021-11-17 15:00:00
# 380564   False   0.986266  2021-01-25 04:00:00
# 431284    True   0.990260  2023-12-21 00:00:00
# 14614    False   0.970991  2022-01-17 10:00:00
# 395991   False   0.973425  2021-01-24 18:00:00
# 243325   False   0.993363  2023-03-07 22:00:00
# 174138   False   0.994929  2021-02-02 05:00:00
# 173351   False   0.962265  2021-02-22 10:00:00
# 513384   False   0.973189  2022-01-17 12:00:00
# 517478   False   0.995364  2023-03-12 01:00:00
# 437370   False   0.963987  2023-03-09 03:00:00
# 315090   False   0.953444  2022-11-07 19:00:00
# 174069    True   0.997264  2021-01-30 08:00:00
# 286730   False   0.962126  2021-12-30 21:00:00
# 177445   False   0.966396  2022-01-01 18:00:00
# 250872   False   0.989184  2021-11-26 02:00:00
# 250885   False   0.979508  2021-11-26 15:00:00
# 330717   False   0.980585  2023-11-13 07:00:00
# 327716    True   0.974611  2023-01-29 06:00:00
# 328339   False   0.968835  2023-02-26 05:00:00
# 173776   False   0.964593  2021-01-18 03:00:00
# 517424   False   0.966627  2023-03-09 19:00:00
# 328001   False   0.954774  2023-02-10 11:00:00
# 506283    True   0.994534  2023-01-22 06:00:00
# 182220   False   0.993085  2023-02-14 22:00:00
# 15208    False   0.952593  2022-02-11 15:00:00
# 119120    True   0.952559  2022-12-27 16:00:00
# 237276   False   0.952061  2021-04-09 18:00:00
# 100606   False   0.957369  2021-03-11 11:00:00
# 125125   False   0.958672  2021-01-19 04:00:00
# 427700    True   0.968478  2023-02-01 10:00:00
# 216298   False   0.969935  2023-03-03 13:00:00
# 252473   False   0.989067  2022-02-02 14:00:00
# 403713   False   0.980406  2021-01-20 05:00:00
# 173775   False   0.969204  2021-01-18 02:00:00
# 281207   False   0.960235  2023-10-03 05:00:00
# 403992    True   0.957453  2021-01-31 21:00:00
# 326988    True   0.988689  2022-12-28 16:00:00
# 181789   False   0.974687  2023-01-27 13:00:00
# 107209   False   0.953583  2023-01-01 08:00:00
# 354251   False   0.994450  2023-02-27 21:00:00
# 406807   False   0.967754  2021-12-30 02:00:00
# 333219   False   0.953274  2021-12-16 18:00:00
# 518476   False   0.956892  2023-04-22 17:00:00
# 47058     True   0.993121  2022-02-10 13:00:00
# 380049   False   0.972831  2021-01-03 17:00:00
# 100675   False   0.985143  2021-03-17 05:00:00
# 30644    False   0.953948  2022-02-22 20:00:00
#
#                                                                                                                  Metar
# 326069                                                     ENNM 191350Z 10010KT 070V130 9999 NCD M00/M10 Q1024 REFZRA=
# 201927                  ENHF 261320Z VRB06G23KT 9999 VCSH DRSN FEW016 BKN036 M07/M12 Q1013 RMK WIND 1254FT 32039G50KT=
# 384220                                                                ENRO 171450Z 23006KT 200V260 CAVOK 02/M03 Q0998=
# 380564                                                 ENRO 250420Z 22003KT 8000NDV BKN004/// OVC005/// M12/M14 Q0997=
# 431284                            ENSG 210020Z 00000KT 0200 R24/0450 FZFG VV002 M03/M03 Q0981 RMK WIND 3806FT 21022KT=
# 14614                                            ENAN 170950Z 34022G34KT 9999 DRSN FEW030 SCT037 BKN055 M01/M05 Q0998=
# 395991                                                              ENRS 241750Z 17014KT 4000 -SN VV004 M01/M03 Q0993=
# 243325                                     ENKB 072150Z 05008KT 2000 SN VV005 M04/M05 Q0990 RMK WIND 745FT 06011G22KT=
# 174138                                                           ENGM 020450Z 02004KT 9999 OVC034 M11/M13 Q1003 NOSIG=
# 173351                                                         ENGK 220950Z 01004KT 340V040 0600 FG VV001 03/03 Q1016=
# 513384                            ENUG 171150Z 35011KT 310V040 9999NDV -SHSN BKN021/// BKN066/// M03/M08 Q0991 W///S4=
# 517478                                  ENUG 120050Z 20018G33KT 9999NDV -SHRA BKN029/// BKN130/// 00/M05 Q0984 W///S5=
# 437370                                  ENSH 090250Z 24008KT 9999 -SN FEW010/// M03/M06 Q0991 RMK WIND 0150FT /////KT=
# 315090                                  ENNA 071920Z 35004KT 9999 FEW016 BKN029 M01/M01 Q1000 RMK WIND 1800FT 04010KT=
# 174069  ENGM 300750Z 00000KT 1000 0450NE R19R/P2000N R01R/P2000N R19L/0600D R01L/1200D FZFG VV002 M15/M16 Q0999 NOSIG=
# 286730                                                                 ENML 302120Z 03007KT 9999NDV NCD M01/M02 Q0996=
# 177445                                       ENGM 011820Z 00000KT 9999 -SN OVC005 M06/M07 Q1012 TEMPO 1200 -SN BKN003=
# 250872                   ENKR 260150Z 35003KT 0100 R05/0400N R23/0450N +SN VV001 M20/M22 Q0998 RMK WIND 731FT 08007KT=
# 250885                                     ENKR 261450Z 17005KT 9999 VCFG BKN001 M23/M26 Q1001 RMK WIND 731FT VRB01KT=
# 330717                                                                       ENNM 130720Z 10012KT CAVOK M02/M07 Q1011=
# 327716                              ENNM 290620Z 03003KT 310V110 9999 -FZRA SCT010/// BKN013/// OVC025/// 01/00 Q0994=
# 328339                                                                      ENNM 260450Z 28005KT 7000 -RA 01/01 Q1021=
# 173776                                                                 ENGM 180250Z 36004KT 9000 BKN004 M08/M09 Q1012=
# 517424                            ENUG 091850Z 01016KT 330V030 6000NDV -SHSN BKN030/// BKN081/// M07/M12 Q0984 W///S5=
# 328001                                                      ENNM 101120Z 22010KT 9999 VCSH SCT028 SCT041 01/M04 Q1007=
# 506283                                   ENTO 220620Z 33002KT 0300 R18/1200N R36/1000N FZFG VV003 M12/M13 Q1038 NOSIG=
# 182220                                                                 ENGM 142220Z VRB01KT 9000 BKN011 M02/M03 Q1027=
# 15208                                                       ENAN 111520Z 30015KT 9999 -SN FEW015 BKN029 M02/M06 Q0997=
# 119120                                                          ENBV 271550Z 21032KT 2000 FZDZBR BKN118 M05/M08 Q0995=
# 237276                          ENKB 091750Z 22015KT 190V250 2000 SHSNRA VV012 01/M03 Q0991 RMK WIND 745FT 23030G44KT=
# 100606                                        ENBS 111120Z 20013G24KT 070V260 9999 3000N 1000S BLSN NSC M12/M15 Q0994=
# 125125                                                                 ENCN 190420Z 05006KT 9999 BKN007 M00/M01 Q1001=
# 427700                      ENSG 011020Z 07003KT 0500 FZFG FEW/// SCT005 BKN035 M02/M02 Q0990 RMK WIND 3806FT 28004KT=
# 216298                                              ENHK 031320Z 28016KT 9999 VCSH FEW011 SCT020 BKN046 M00/M02 Q0993=
# 252473                                      ENKR 021420Z 18005KT 1700 PRFG VV003 M20/M22 Q1011 RMK WIND 731FT 36010KT=
# 403713                                                            ENRY 200520Z 06006KT 8000NDV OVC003/// 01/M00 Q0996=
# 173775                                                              ENGM 180220Z 35003KT 4000 BR OVC002 M08/M09 Q1012=
# 281207                                                           ENMH 030450Z 17004KT 9999 SCT037 BKN064 00/M01 Q1002=
# 403992                                   ENRY 312120Z 12002KT 0150NDV R12/0800 R30/0800N FZFG OVC000/// M08/M09 Q0998=
# 326988                                                              ENNM 281550Z 09015KT 9999 -FZRA NCD M03/M07 Q1000=
# 181789                                                                 ENGM 271250Z 21003KT CAVOK M04/M06 Q1025 NOSIG=
# 107209                                          ENBS 010820Z 16008KT 9999 BKN008/// BKN011/// OVC027/// M03/M04 Q0982=
# 354251                   ENOV 272050Z 00000KT 1000 DZ BR VV008 02/02 Q1036 RMK WIND RWY24 VRB02KT WIND 2090FT 34007KT=
# 406807                                                       ENRY 300220Z 12007KT 1700NDV -SN OVC004/// M00/M01 Q0998=
# 333219                                                                       ENNO 161750Z 00000KT CAVOK M05/M06 Q1030=
# 518476                                      ENUG 221720Z 32020KT 250V340 1700NDV -SHSN BKN012/// M04/M06 Q1007 W///S5=
# 47058                                                              ENBJ 101250Z 05004KT 0800 FZFG VV004 M04/M04 Q0975=
# 380049                                                                       ENRO 031650Z 00000KT CAVOK M23/M26 Q1031=
# 100675                                               ENBS 170520Z 29028KT 9999 4000N BLSN FEW007 SCT038 M09/M11 Q1009=
# 30644                                                 ENAT 222020Z 17004KT CAVOK M19/M21 Q1002 RMK WIND 700FT 18008KT=

# %%
comparison_df[comparison_df['Actual'] == True].head(50)
# Out:
#         Actual  Predicted                 Time  \
# 505912    True   0.978720  2023-01-06 18:00:00
# 326069    True   0.980900  2022-11-19 14:00:00
# 501905    True   0.858779  2021-12-09 02:00:00
# 431284    True   0.896447  2023-12-21 00:00:00
# 145976    True   0.930844  2023-02-02 06:00:00
# 500276    True   0.895710  2021-03-10 03:00:00
# 494560    True   0.046970  2023-02-28 19:00:00
# 411096    True   0.257747  2023-02-07 03:00:00
# 174069    True   0.993087  2021-01-30 08:00:00
# 125831    True   0.346773  2021-02-17 14:00:00
# 327716    True   0.913942  2023-01-29 06:00:00
# 506283    True   0.987668  2023-01-22 06:00:00
# 119120    True   0.967570  2022-12-27 16:00:00
# 427700    True   0.948036  2023-02-01 10:00:00
# 388338    True   0.959781  2022-09-07 05:00:00
# 32207     True   0.203170  2022-05-02 05:00:00
# 153347    True   0.818994  2021-04-30 03:00:00
# 328030    True   0.833866  2023-02-11 16:00:00
# 403992    True   0.901730  2021-01-31 21:00:00
# 326988    True   0.991380  2022-12-28 16:00:00
# 414031    True   0.611751  2023-12-10 07:00:00
# 327384    True   0.825961  2023-01-14 02:00:00
# 176201    True   0.037729  2021-11-05 15:00:00
# 47058     True   0.974097  2022-02-10 13:00:00
# 392764    True   0.712492  2023-04-09 03:00:00
# 535988    True   0.679102  2022-02-01 04:00:00
# 180029    True   0.953579  2022-11-08 05:00:00
# 486727    True   0.004925  2021-11-10 03:00:00
# 177465    True   0.989742  2022-01-02 14:00:00
# 164935    True   0.030626  2023-11-11 10:00:00
# 499911    True   0.931321  2021-02-17 15:00:00
# 333161    True   0.573906  2021-12-10 09:00:00
# 327448    True   0.946883  2023-01-17 01:00:00
# 14237     True   0.982757  2021-12-31 17:00:00
# 141178    True   0.363187  2022-02-24 23:00:00
# 517398    True   0.994869  2023-03-08 17:00:00
# 330014    True   0.924151  2023-10-14 10:00:00
# 330099    True   0.685718  2023-10-18 07:00:00
# 466870    True   0.992204  2022-04-26 19:00:00
# 330594    True   0.927422  2023-11-08 04:00:00
# 410418    True   0.528407  2023-01-07 04:00:00
# 246451    True   0.836420  2021-01-20 17:00:00
# 344479    True   0.931191  2023-02-22 06:00:00
# 236614    True   0.995177  2021-03-06 22:00:00
# 199384    True   0.123054  2022-01-08 04:00:00
# 431142    True   0.665740  2023-12-14 07:00:00
# 326410    True   0.987440  2022-12-04 07:00:00
# 307171    True   0.017022  2021-03-17 23:00:00
# 327881    True   0.643232  2023-02-05 04:00:00
# 13305     True   0.946843  2021-11-21 20:00:00
#
#                                                                                                                                                              Metar
# 505912                                                                                        ENTO 061820Z 03006KT 3200 -SN OVC002 M02/M02 Q1005 TEMPO 4000 -FZDZ=
# 326069                                                                                                 ENNM 191350Z 10010KT 070V130 9999 NCD M00/M10 Q1024 REFZRA=
# 501905                                                                                     ENTO 090220Z 10005KT 080V130 2600 -FZDZ OVC004/// M01/M01 Q1010 REFZDZ=
# 431284                                                                        ENSG 210020Z 00000KT 0200 R24/0450 FZFG VV002 M03/M03 Q0981 RMK WIND 3806FT 21022KT=
# 145976  ENDU 020620Z 00000KT 2500 1000E R10/1200U R28/1200D PRFG BR SCT002 BKN004 M15/M16 Q1009 TEMPO 0700 FZFG VV002 RMK WIND 1100FT VRB01KT WIND 2200FT 34005KT=
# 500276                                                                                             ENTO 100320Z 10007KT 050V140 9999 FZUP OVC020/// M01/M05 Q1019=
# 494560                                                ENTC 281920Z 26004KT 5000 -SHSN BKN004 M01/M01 Q1016 TEMPO 3000 -FZDZ SCT003 BKN020 RMK WIND 2600FT 24010KT=
# 411096                                                               ENRY 070320Z VRB01KT 0350NDV R12/1500U R30/1200V1900D FZFG FEW000/// BKN190/// M03/M03 Q1033=
# 174069                                              ENGM 300750Z 00000KT 1000 0450NE R19R/P2000N R01R/P2000N R19L/0600D R01L/1200D FZFG VV002 M15/M16 Q0999 NOSIG=
# 125831                                                                                                       ENCN 171350Z 04011KT 9999 -FZDZ BKN010 M01/M03 Q1013=
# 327716                                                                          ENNM 290620Z 03003KT 310V110 9999 -FZRA SCT010/// BKN013/// OVC025/// 01/00 Q0994=
# 506283                                                                               ENTO 220620Z 33002KT 0300 R18/1200N R36/1000N FZFG VV003 M12/M13 Q1038 NOSIG=
# 119120                                                                                                      ENBV 271550Z 21032KT 2000 FZDZBR BKN118 M05/M08 Q0995=
# 427700                                                                  ENSG 011020Z 07003KT 0500 FZFG FEW/// SCT005 BKN035 M02/M02 Q0990 RMK WIND 3806FT 28004KT=
# 388338                                                                                                  ENRO 070450Z 00000KT 0300 R31/0450 FZFG NSC M03/M04 Q1022=
# 32207                                                                             ENAT 020520Z VRB03KT 3000 -SN VV008 M01/M02 Q0995 REFZRA RMK WIND 700FT 13010KT=
# 153347                                                              ENEV 300320Z 34008KT 9999 FZUP FEW021/// OVC061/// M01/M05 Q1010 REDZ RMK WIND 1400FT 33015KT=
# 328030                                                                                                 ENNM 111550Z 09004KT 050V130 9999 NCD M03/M04 Q1019 REFZRA=
# 403992                                                                               ENRY 312120Z 12002KT 0150NDV R12/0800 R30/0800N FZFG OVC000/// M08/M09 Q0998=
# 326988                                                                                                          ENNM 281550Z 09015KT 9999 -FZRA NCD M03/M07 Q1000=
# 414031                                                                                               ENRY 100720Z 05008KT 4400 -FZRA OVC003/// M00/M01 Q1009 RESG=
# 327384                                                                                                 ENNM 140150Z 00000KT 7000 FZDZ FEW002 OVC007 M00/M01 Q0997=
# 176201                         ENGM 051520Z 16003KT 140V200 0550 0350SW R19R/0700U R01R/1000U R19L/1400U R01L/0350N FZFG VV001 M00/M00 Q1004 TEMPO 2000 BR BKN003=
# 47058                                                                                                          ENBJ 101250Z 05004KT 0800 FZFG VV004 M04/M04 Q0975=
# 392764                                                                                            ENRO 090320Z 00000KT 0300 R31/0400 FZFG OVC001/// M08/M09 Q1031=
# 535988                                                                           ENVD 010350Z 19009KT 170V230 9999 FZFG SCT007 M08/M10 Q1005 RMK ARCTIC SEA SMOKE=
# 180029                                       ENGM 080520Z VRB02KT 0750 0250N R19R/0400N R01R/0600N R19L/2000D R01L/1000D FZFG VV002 M00/M01 Q1002 TEMPO 0500 FZFG=
# 486727                                                                               ENTC 100320Z 20020KT 9999 OVC034 05/M00 Q0987 REFZRA RMK WIND 2600FT 19035KT=
# 177465                                                       ENGM 021350Z 00000KT 0750 R19R/1100D R01R/0650N R19L/1100N R01L/1100D FZFG VV002 M00/M00 Q0995 NOSIG=
# 164935                                                                                 ENEV 110948Z VRB01KT 0700 FZFG VV002 M08/M09 Q1018 RMK WIND 1400FT 09008KT=
# 499911                                                                    ENTO 171520Z 04005KT 360V060 6000 SG SCT002 BKN005 M01/M01 Q1016 TEMPO 3000 -FZDZ VV004=
# 333161                                                                                                       ENNO 100920Z 29004KT 8000 -FZDZ BKN018 M01/M02 Q1005=
# 327448                                                                                                         ENNM 170120Z 04010KT 9999 NCD M04/M05 Q0986 REFZRA=
# 14237                                                                             ENAN 311650Z 09016KT 9999 FZUP SCT010/// BKN025/// BKN041/// M02/M03 Q1007 RESN=
# 141178                                      ENDU 242320Z 00000KT 0600 R10/P2000D R28/P2000N FZFG SCT035 M12/M13 Q0974 RMK WIND 1100FT 15005KT WIND 2200FT 18007KT=
# 517398                                                                                    ENUG 081720Z 25024G36KT 0900NDV SN FZFG NCD M03/M06 Q0986 REFZRA W///S4=
# 330014                                                                                                       ENNM 141020Z 06015KT 9999 -RA NCD 01/01 Q0971 REFZRA=
# 330099                                                                                                        ENNM 180720Z 06008KT 0600 FZFG BKN000 M01/M01 Q1019=
# 466870                                                                             ENSS 261920Z 29028KT 1000 VCSH FZFG VV005 M08/M09 Q1007 RMK WIND 500FT 28041KT=
# 330594                                                                                          ENNM 080350Z 06011KT 9999 BKN037/// OVC084/// 00/M01 Q1002 REFZRA=
# 410418                                                                       ENRY 070350Z 11002KT 0450NDV R12/P2000D R30/1400VP2000D FZFG OVC002/// M02/M02 Q1008=
# 246451                                                                                 ENKR 201650Z 17009KT 0700 FZFG BKN001 M21/M23 Q1018 RMK WIND 731FT 07007KT=
# 344479                                                                                                 ENOL 220550Z 13021KT 9999 BKN040 M00/M06 Q1007 TEMPO -FZRA=
# 236614                                                       ENKB 062220Z 27020KT 3400 FZUP SCT002/// BKN021/// OVC033/// M01/M03 Q1014 RMK WIND 745FT 30035G47KT=
# 199384                                                            ENHF 080350Z 23020KT 9999 FEW013/// BKN023/// M01/M04 Q0995 RESG REFZUP RMK WIND 1254FT 26021KT=
# 431142                                                           ENSG 140650Z 06004KT 9999 VCFG FEW/// SCT007 BKN023 M05/M06 Q1010 REFZDZ RMK WIND 3806FT 19013KT=
# 326410                                                                                                          ENNM 040720Z 07010KT 9999 -FZRA NCD M07/M09 Q1034=
# 307171                                                                 ENNA 172250Z 34016KT 9999 FEW043/// BKN064/// M05/M08 Q1018 REFZDZ RMK WIND 1800FT 33019KT=
# 327881                                                                                ENNM 050350Z 06004KT 9999 -FZRA SCT013/// BKN030/// BKN042/// M03/M04 Q1021=
# 13305                                                                         ENAN 212020Z 24006KT 210V280 9999 -FZRA FEW007/// SCT022/// BKN042/// M03/M06 Q1007=

# %%
# confusion matrix
cmap1 = sns.diverging_palette(260,-10,s=50, l=75, n=5, as_cmap=True)
plt.subplots(figsize=(10,6))
cf_matrix = confusion_matrix(y_test, y_pred_val)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot: >

# %%
conf_matrix = confusion_matrix(y_test, y_pred_val)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap=cmap1, cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Instantaneous: Confusion Matrix threshold for y_pred > 0.8')
plt.savefig('cmap_instantaneous_0.8.png')
plt.show()
