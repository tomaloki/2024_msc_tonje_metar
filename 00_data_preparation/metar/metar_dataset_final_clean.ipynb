# %% [markdown]
# ## METAR

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xarray as xr
import time

# %%
metar_data = pd.read_csv('../data/metar_msg_overview.csv')

# %%
metar_data
# Out:
#         airport_identifier            issued_at  \
# 0                     ENDR  2021-01-01 00:20:00
# 1                     ENZV  2021-01-01 00:20:00
# 2                     ENTC  2021-01-01 00:20:00
# 3                     ENSB  2021-01-01 00:20:00
# 4                     ENGM  2021-01-01 00:20:00
# ...                    ...                  ...
# 3275708               ENLA  2023-12-31 23:50:00
# 3275709               ENUS  2023-12-31 23:50:00
# 3275710               ENOL  2023-12-31 23:50:00
# 3275711               ENWV  2023-12-31 23:50:00
# 3275712               ENHO  2023-12-31 23:50:00
#
#                                                      metar metartype
# 0                       ENDR 010020Z 14007KT 03/M02 Q1006=      AUTO
# 1        ENZV 010020Z 13006KT 9999 SCT026 BKN035 03/01 ...       NaN
# 2        ENTC 010020Z 21015KT CAVOK 02/M03 Q1013 RMK WI...       NaN
# 3        ENSB 010020Z 24004KT 9999 -SN FEW009 BKN033 M0...       NaN
# 4        ENGM 010020Z 36006KT 9999 4900E -SN FEW009 OVC...       NaN
# ...                                                    ...       ...
# 3275708  ENLA 312350Z 11021KT 9999NDV BKN036/// 07/06 Q...      AUTO
# 3275709  ENUS 312350Z 10033G43KT 9999NDV BKN022/// 00/M...      AUTO
# 3275710  ENOL 312350Z 12029G41KT 9999 DRSN NSC M03/M09 ...       NaN
# 3275711  ENWV 312350Z 14019KT 9999NDV SCT014/// OVC037/...      AUTO
# 3275712  ENHO 312350Z 16011KT 9999 -SN BKN035 M01/M03 Q...       NaN
#
# [3275713 rows x 4 columns]

# %% [markdown]
# Checking for nan and null values

# %%
metar_data.isna().any()
# Out:
# airport_identifier    False
# issued_at             False
# metar                 False
# metartype              True
# dtype: bool

# %%
metar_data.isnull().any()
# Out:
# airport_identifier    False
# issued_at             False
# metar                 False
# metartype              True
# dtype: bool

# %% [markdown]
# Metartype columns with NaN are manual messages. Filling these rows with 'MANUAL'

# %%
# Replace NaN with MANUAL
metar_data['metartype'].fillna('MANUAL', inplace=True)

# %%
metar_data[metar_data.duplicated(subset=['airport_identifier', 'issued_at'], keep=False)]
# Out:
#         airport_identifier            issued_at  \
# 434                   ENKB  2021-01-01 04:50:00
# 439                   ENKB  2021-01-01 04:50:00
# 490                   ENGM  2021-01-01 05:50:00
# 491                   ENGM  2021-01-01 05:50:00
# 545                   ENBO  2021-01-01 06:20:00
# ...                    ...                  ...
# 3275040               ENBN  2023-12-31 18:20:00
# 3275044               ENTO  2023-12-31 18:50:00
# 3275055               ENTO  2023-12-31 18:50:00
# 3275616               ENAT  2023-12-31 23:20:00
# 3275650               ENAT  2023-12-31 23:20:00
#
#                                                      metar metartype
# 434      ENKB 010450Z 11004KT 070V150 9999 BKN090/// M0...      AUTO
# 439      ENKB 010450Z 11004KT 070V150 CAVOK M01/M03 Q10...       COR
# 490      ENGM 010550Z 02006KT 9999 -SN BKN014 M02/M03 Q...       COR
# 491      ENGM 010550Z 02006KT 9999 -SN BKN014 M02/M03 Q...    MANUAL
# 545      ENBO 010620Z 09011KT 9999 BKN060 02/M05 Q1011 ...    MANUAL
# ...                                                    ...       ...
# 3275040  ENBN 311820Z 09013KT 060V120 CAVOK M04/M10 Q1015=       COR
# 3275044  ENTO 311850Z 03013KT 1000 SN VV007 M04/M04 Q10...    MANUAL
# 3275055  ENTO 311850Z 03013KT 1000 SN VV007 M04/M04 Q10...       COR
# 3275616  ENAT 312320Z 15013KT 9999 NCD M09/M14 Q1023 RM...      AUTO
# 3275650  ENAT 312320Z 15013KT CAVOK M09/M14 Q1023 RMK W...       COR
#
# [59442 rows x 4 columns]

# %% [markdown]
# ## Handling duplicated values

# %% [markdown]
# Listing metartypes based on priority

# %%
metartype_prio = ['SPECI', 'COR', 'MANUAL', 'AUTO']

# %%
# Sorting the metar data based on the priority list

# %%
metar_data_sorted= metar_data.sort_values(by=['metartype'], key=lambda x: x.map({metartype: metartype_prio.index(metartype) for metartype in metartype_prio}))

# %%
metar_data_sorted
# Out:
#         airport_identifier            issued_at  \
# 1017293               ENBS  2022-01-25 16:26:00
# 1448143               ENRS  2022-06-24 10:34:00
# 2930725               ENVD  2023-09-23 10:30:00
# 1426855               ENSS  2022-06-17 14:32:00
# 1426856               ENBV  2022-06-17 14:33:00
# ...                    ...                  ...
# 2032606               ENLA  2022-12-24 23:50:00
# 2032605               ENFB  2022-12-24 23:50:00
# 2032604               ENSE  2022-12-24 23:50:00
# 2032615               ENSL  2022-12-24 23:50:00
# 0                     ENDR  2021-01-01 00:20:00
#
#                                                      metar metartype
# 1017293  ENBS 251626Z 27028KT 1000 SN BLSN VV005 M03/M0...     SPECI
# 1448143  ENRS 241034Z 19008KT 9999 FEW006 SCT028 BKN037...     SPECI
# 2930725  ENVD 231030Z 28014KT 6000 RA FEW003 BKN010 BKN...     SPECI
# 1426855  ENSS 171432Z 36010KT 9999 FEW007 SCT015 OVC026...     SPECI
# 1426856  ENBV 171433Z 03008KT 9999 FEW012 SCT022 BKN032...     SPECI
# ...                                                    ...       ...
# 2032606  ENLA 242350Z 16031KT 9000NDV BKN007/// BKN130/...      AUTO
# 2032605  ENFB 242350Z 14042KT 5000NDV -SHRA BKN011/// 0...      AUTO
# 2032604  ENSE 242350Z 14043KT 9999NDV -RA OVC019/// 05/...      AUTO
# 2032615  ENSL 242350Z 16037KT 9999NDV BKN009/// BKN090/...      AUTO
# 0                       ENDR 010020Z 14007KT 03/M02 Q1006=      AUTO
#
# [3275713 rows x 4 columns]

# %% [markdown]
# Remove duplicates based 'airport_identifier' and 'issued', keeping first occurrence of metartype in the prioritized order

# %%
metar_data_no_duplicates = metar_data_sorted.drop_duplicates(subset=['airport_identifier', 'issued_at'])

# %%
metar_data_no_duplicates
# Out:
#         airport_identifier            issued_at  \
# 1017293               ENBS  2022-01-25 16:26:00
# 1448143               ENRS  2022-06-24 10:34:00
# 2930725               ENVD  2023-09-23 10:30:00
# 1426855               ENSS  2022-06-17 14:32:00
# 1426856               ENBV  2022-06-17 14:33:00
# ...                    ...                  ...
# 2032606               ENLA  2022-12-24 23:50:00
# 2032605               ENFB  2022-12-24 23:50:00
# 2032604               ENSE  2022-12-24 23:50:00
# 2032615               ENSL  2022-12-24 23:50:00
# 0                     ENDR  2021-01-01 00:20:00
#
#                                                      metar metartype
# 1017293  ENBS 251626Z 27028KT 1000 SN BLSN VV005 M03/M0...     SPECI
# 1448143  ENRS 241034Z 19008KT 9999 FEW006 SCT028 BKN037...     SPECI
# 2930725  ENVD 231030Z 28014KT 6000 RA FEW003 BKN010 BKN...     SPECI
# 1426855  ENSS 171432Z 36010KT 9999 FEW007 SCT015 OVC026...     SPECI
# 1426856  ENBV 171433Z 03008KT 9999 FEW012 SCT022 BKN032...     SPECI
# ...                                                    ...       ...
# 2032606  ENLA 242350Z 16031KT 9000NDV BKN007/// BKN130/...      AUTO
# 2032605  ENFB 242350Z 14042KT 5000NDV -SHRA BKN011/// 0...      AUTO
# 2032604  ENSE 242350Z 14043KT 9999NDV -RA OVC019/// 05/...      AUTO
# 2032615  ENSL 242350Z 16037KT 9999NDV BKN009/// BKN090/...      AUTO
# 0                       ENDR 010020Z 14007KT 03/M02 Q1006=      AUTO
#
# [3244813 rows x 4 columns]

# %%
metar_data_no_duplicates[metar_data_no_duplicates.duplicated(subset=['airport_identifier', 'issued_at'])]
# Out:
# Empty DataFrame
# Columns: [airport_identifier, issued_at, metar, metartype]
# Index: []

# %%
no_duplicates_left = metar_data_no_duplicates.duplicated(subset=['airport_identifier', 'issued_at']).sum() == 0

if no_duplicates_left:
    print("No duplicates left in the DataFrame.")
else:
    print("There are still duplicates in the DataFrame.")
# Out:
# No duplicates left in the DataFrame.

# %% [markdown]
# ## Extract airports where FZ has been registered in METAR

# %%
# Add FZ column
metar_data_no_duplicates['contain_FZ'] = metar_data_no_duplicates['metar'].str.contains('FZ').astype(bool)
# Out:
# /tmp/ipykernel_1456266/4023523156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metar_data_no_duplicates['contain_FZ'] = metar_data_no_duplicates['metar'].str.contains('FZ').astype(bool)

# %%
print(f'Number of airports: {metar_data_no_duplicates["airport_identifier"].nunique()}')
print(f'Number of airports with registered FZ in metar: {metar_data_no_duplicates[metar_data_no_duplicates["contain_FZ"]]["airport_identifier"].nunique()}')
# Out:
# Number of airports: 82
# Number of airports with registered FZ in metar: 74

# %%
metar_data_with_FZ = metar_data_no_duplicates[metar_data_no_duplicates["contain_FZ"]]["airport_identifier"].unique()

# %%
metar_data_filtered = metar_data_no_duplicates[metar_data_no_duplicates['airport_identifier'].isin(metar_data_with_FZ)]

# %%
metar_data_filtered
# Out:
#         airport_identifier            issued_at  \
# 1017293               ENBS  2022-01-25 16:26:00
# 1448143               ENRS  2022-06-24 10:34:00
# 2930725               ENVD  2023-09-23 10:30:00
# 1426855               ENSS  2022-06-17 14:32:00
# 1426856               ENBV  2022-06-17 14:33:00
# ...                    ...                  ...
# 2032606               ENLA  2022-12-24 23:50:00
# 2032605               ENFB  2022-12-24 23:50:00
# 2032604               ENSE  2022-12-24 23:50:00
# 2032615               ENSL  2022-12-24 23:50:00
# 0                     ENDR  2021-01-01 00:20:00
#
#                                                      metar metartype  \
# 1017293  ENBS 251626Z 27028KT 1000 SN BLSN VV005 M03/M0...     SPECI
# 1448143  ENRS 241034Z 19008KT 9999 FEW006 SCT028 BKN037...     SPECI
# 2930725  ENVD 231030Z 28014KT 6000 RA FEW003 BKN010 BKN...     SPECI
# 1426855  ENSS 171432Z 36010KT 9999 FEW007 SCT015 OVC026...     SPECI
# 1426856  ENBV 171433Z 03008KT 9999 FEW012 SCT022 BKN032...     SPECI
# ...                                                    ...       ...
# 2032606  ENLA 242350Z 16031KT 9000NDV BKN007/// BKN130/...      AUTO
# 2032605  ENFB 242350Z 14042KT 5000NDV -SHRA BKN011/// 0...      AUTO
# 2032604  ENSE 242350Z 14043KT 9999NDV -RA OVC019/// 05/...      AUTO
# 2032615  ENSL 242350Z 16037KT 9999NDV BKN009/// BKN090/...      AUTO
# 0                       ENDR 010020Z 14007KT 03/M02 Q1006=      AUTO
#
#          contain_FZ
# 1017293       False
# 1448143       False
# 2930725       False
# 1426855       False
# 1426856       False
# ...             ...
# 2032606       False
# 2032605       False
# 2032604       False
# 2032615       False
# 0             False
#
# [3100972 rows x 5 columns]

# %%
# Convert issued_at to datetime
metar_data_filtered['issued_at'] = pd.to_datetime(metar_data_filtered['issued_at'])
# Out:
# /tmp/ipykernel_1456266/3399434864.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metar_data_filtered['issued_at'] = pd.to_datetime(metar_data_filtered['issued_at'])

# %%
# Add 'time' column for rounding 'issued_at'

# %%
metar_data_filtered['time'] = metar_data_filtered['issued_at'].dt.round('H')
# Out:
# /tmp/ipykernel_1456266/4098504051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metar_data_filtered['time'] = metar_data_filtered['issued_at'].dt.round('H')

# %%
metar_data_filtered
# Out:
#         airport_identifier           issued_at  \
# 1017293               ENBS 2022-01-25 16:26:00
# 1448143               ENRS 2022-06-24 10:34:00
# 2930725               ENVD 2023-09-23 10:30:00
# 1426855               ENSS 2022-06-17 14:32:00
# 1426856               ENBV 2022-06-17 14:33:00
# ...                    ...                 ...
# 2032606               ENLA 2022-12-24 23:50:00
# 2032605               ENFB 2022-12-24 23:50:00
# 2032604               ENSE 2022-12-24 23:50:00
# 2032615               ENSL 2022-12-24 23:50:00
# 0                     ENDR 2021-01-01 00:20:00
#
#                                                      metar metartype  \
# 1017293  ENBS 251626Z 27028KT 1000 SN BLSN VV005 M03/M0...     SPECI
# 1448143  ENRS 241034Z 19008KT 9999 FEW006 SCT028 BKN037...     SPECI
# 2930725  ENVD 231030Z 28014KT 6000 RA FEW003 BKN010 BKN...     SPECI
# 1426855  ENSS 171432Z 36010KT 9999 FEW007 SCT015 OVC026...     SPECI
# 1426856  ENBV 171433Z 03008KT 9999 FEW012 SCT022 BKN032...     SPECI
# ...                                                    ...       ...
# 2032606  ENLA 242350Z 16031KT 9000NDV BKN007/// BKN130/...      AUTO
# 2032605  ENFB 242350Z 14042KT 5000NDV -SHRA BKN011/// 0...      AUTO
# 2032604  ENSE 242350Z 14043KT 9999NDV -RA OVC019/// 05/...      AUTO
# 2032615  ENSL 242350Z 16037KT 9999NDV BKN009/// BKN090/...      AUTO
# 0                       ENDR 010020Z 14007KT 03/M02 Q1006=      AUTO
#
#          contain_FZ                time
# 1017293       False 2022-01-25 16:00:00
# 1448143       False 2022-06-24 11:00:00
# 2930725       False 2023-09-23 10:00:00
# 1426855       False 2022-06-17 15:00:00
# 1426856       False 2022-06-17 15:00:00
# ...             ...                 ...
# 2032606       False 2022-12-25 00:00:00
# 2032605       False 2022-12-25 00:00:00
# 2032604       False 2022-12-25 00:00:00
# 2032615       False 2022-12-25 00:00:00
# 0             False 2021-01-01 00:00:00
#
# [3100972 rows x 6 columns]

# %%
metar_data_filtered[(metar_data_filtered['airport_identifier'] == 'ENWG') &( metar_data_filtered['contain_FZ'] == True)]
# Out:
#         airport_identifier           issued_at  \
# 2251986               ENWG 2023-03-06 02:50:00
# 2251918               ENWG 2023-03-06 02:20:00
# 2263050               ENWG 2023-03-09 11:50:00
#
#                                                      metar metartype  \
# 2251986  ENWG 060250Z 34003KT 9999NDV -RA SCT007/// OVC...      AUTO
# 2251918  ENWG 060220Z 30006KT 9999NDV -FZRA FEW005/// O...      AUTO
# 2263050  ENWG 091150Z 30029KT 9999NDV -RA FEW024/// BKN...      AUTO
#
#          contain_FZ                time
# 2251986        True 2023-03-06 03:00:00
# 2251918        True 2023-03-06 02:00:00
# 2263050        True 2023-03-09 12:00:00

# %% [markdown]
# ENWG airport is not registered in airport locations, and only has 3 METAR messages with FZ (AUTO-generated). Removing this airport_identifier.

# %%
metar_data_filtered = metar_data_filtered[metar_data_filtered['airport_identifier'] != 'ENWG']

# %%
print(f'Total unique timnestamps: {metar_data_filtered["time"].nunique()}')
# Out:
# Total unique timnestamps: 26281

# %%
# Drop duplicated timestamps after rounding
metar_data_final = metar_data_filtered.drop_duplicates(subset=['airport_identifier', 'time'])

# %%
metar_data_final
# Out:
#         airport_identifier           issued_at  \
# 1017293               ENBS 2022-01-25 16:26:00
# 1448143               ENRS 2022-06-24 10:34:00
# 2930725               ENVD 2023-09-23 10:30:00
# 1426855               ENSS 2022-06-17 14:32:00
# 1426856               ENBV 2022-06-17 14:33:00
# ...                    ...                 ...
# 2032632               ENSR 2022-12-25 00:20:00
# 2032589               ENRA 2022-12-24 23:50:00
# 2032578               ENBS 2022-12-24 23:50:00
# 2032628               ENSD 2022-12-25 00:20:00
# 0                     ENDR 2021-01-01 00:20:00
#
#                                                      metar metartype  \
# 1017293  ENBS 251626Z 27028KT 1000 SN BLSN VV005 M03/M0...     SPECI
# 1448143  ENRS 241034Z 19008KT 9999 FEW006 SCT028 BKN037...     SPECI
# 2930725  ENVD 231030Z 28014KT 6000 RA FEW003 BKN010 BKN...     SPECI
# 1426855  ENSS 171432Z 36010KT 9999 FEW007 SCT015 OVC026...     SPECI
# 1426856  ENBV 171433Z 03008KT 9999 FEW012 SCT022 BKN032...     SPECI
# ...                                                    ...       ...
# 2032632  ENSR 250020Z VRB03KT 9999 NCD M07/M09 Q1000 RM...      AUTO
# 2032589  ENRA 242350Z 34002KT 9999 -FZDZ OVC013/// M08/...      AUTO
# 2032578  ENBS 242350Z 35008KT 9999 OVC030/// M03/M08 Q0...      AUTO
# 2032628  ENSD 250020Z 14008KT 9999 NCD M05/M08 Q1008 RM...      AUTO
# 0                       ENDR 010020Z 14007KT 03/M02 Q1006=      AUTO
#
#          contain_FZ                time
# 1017293       False 2022-01-25 16:00:00
# 1448143       False 2022-06-24 11:00:00
# 2930725       False 2023-09-23 10:00:00
# 1426855       False 2022-06-17 15:00:00
# 1426856       False 2022-06-17 15:00:00
# ...             ...                 ...
# 2032632       False 2022-12-25 00:00:00
# 2032589        True 2022-12-25 00:00:00
# 2032578       False 2022-12-25 00:00:00
# 2032628       False 2022-12-25 00:00:00
# 0             False 2021-01-01 00:00:00
#
# [1598954 rows x 6 columns]

# %%
# Sort values based on 'airport_identifier' and 'time'
metar_data_final.sort_values(['airport_identifier', 'time'], inplace=True)

# Group by airport
metar_data_final.groupby(['airport_identifier'])
# Out:
# /tmp/ipykernel_1456266/2274676210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metar_data_final.sort_values(['airport_identifier', 'time'], inplace=True)

# %%
# Check for a specific airport
metar_data_final[(metar_data_final['airport_identifier'] == 'ENGM') & (metar_data_final['contain_FZ'] == True)]
# Out:
#         airport_identifier           issued_at  \
# 23884                 ENGM 2021-01-10 13:50:00
# 24005                 ENGM 2021-01-10 14:50:00
# 24423                 ENGM 2021-01-10 18:20:00
# 24551                 ENGM 2021-01-10 19:20:00
# 24673                 ENGM 2021-01-10 20:20:00
# ...                    ...                 ...
# 3273134               ENGM 2023-12-31 05:20:00
# 3273197               ENGM 2023-12-31 05:50:00
# 3273418               ENGM 2023-12-31 07:20:00
# 3274575               ENGM 2023-12-31 15:20:00
# 3274710               ENGM 2023-12-31 16:20:00
#
#                                                      metar metartype  \
# 23884    ENGM 101350Z 00000KT 0300 R19R/0400N R01R/0350...    MANUAL
# 24005    ENGM 101450Z 04002KT 5000 0900N R19R/1300U R01...    MANUAL
# 24423    ENGM 101820Z 00000KT 1000 R19R/0700N R01R/P200...    MANUAL
# 24551    ENGM 101920Z VRB02KT 0800 R19R/1700U R01R/0450...    MANUAL
# 24673    ENGM 102020Z VRB01KT 0500 R19R/0600N R01R/1100...    MANUAL
# ...                                                    ...       ...
# 3273134  ENGM 310520Z 08003KT 050V110 9999 -FZDZ SCT007...    MANUAL
# 3273197  ENGM 310550Z 07004KT 9999 -FZDZ FEW007 OVC010 ...    MANUAL
# 3273418  ENGM 310720Z 07004KT 9999 OVC011 M04/M05 Q1012...    MANUAL
# 3274575  ENGM 311520Z 07008KT 8000 -FZDZ OVC008 M05/M07...    MANUAL
# 3274710  ENGM 311620Z 04006KT 010V070 8000 -FZDZ FEW007...    MANUAL
#
#          contain_FZ                time
# 23884          True 2021-01-10 14:00:00
# 24005          True 2021-01-10 15:00:00
# 24423          True 2021-01-10 18:00:00
# 24551          True 2021-01-10 19:00:00
# 24673          True 2021-01-10 20:00:00
# ...             ...                 ...
# 3273134        True 2023-12-31 05:00:00
# 3273197        True 2023-12-31 06:00:00
# 3273418        True 2023-12-31 07:00:00
# 3274575        True 2023-12-31 15:00:00
# 3274710        True 2023-12-31 16:00:00
#
# [559 rows x 6 columns]

# %%
# Set airport and issued_at as index
#metar_data_final.set_index(['airport_identifier', 'time'], inplace=True, drop=True)

# %%
metar_data_final
# Out:
#         airport_identifier           issued_at  \
# 10                    ENAL 2021-01-01 00:20:00
# 95                    ENAL 2021-01-01 01:20:00
# 140                   ENAL 2021-01-01 01:50:00
# 267                   ENAL 2021-01-01 03:20:00
# 360                   ENAL 2021-01-01 04:20:00
# ...                    ...                 ...
# 3275166               ENZV 2023-12-31 19:50:00
# 3275285               ENZV 2023-12-31 20:50:00
# 3275473               ENZV 2023-12-31 22:20:00
# 3275588               ENZV 2023-12-31 22:50:00
# 3275653               ENZV 2023-12-31 23:50:00
#
#                                                      metar metartype  \
# 10       ENAL 010020Z 08005KT 9999 SCT024/// BKN037/// ...      AUTO
# 95       ENAL 010120Z 08005KT 9999 FEW027/// SCT040/// ...      AUTO
# 140      ENAL 010150Z 09006KT 9999 BKN025/// M01/M02 Q1...      AUTO
# 267      ENAL 010320Z 09006KT 9999 OVC025/// 01/M02 Q1006=      AUTO
# 360      ENAL 010420Z 17003KT 9999 OVC028/// 01/M01 Q1006=      AUTO
# ...                                                    ...       ...
# 3275166           ENZV 311950Z 10017KT CAVOK 05/M04 Q0994=    MANUAL
# 3275285           ENZV 312050Z 10018KT CAVOK 05/M04 Q0994=    MANUAL
# 3275473        ENZV 312220Z 10023G34KT CAVOK 05/M05 Q0994=    MANUAL
# 3275588           ENZV 312250Z 10021KT CAVOK 05/M04 Q0994=    MANUAL
# 3275653        ENZV 312350Z 11025G37KT CAVOK 04/M05 Q0995=    MANUAL
#
#          contain_FZ                time
# 10            False 2021-01-01 00:00:00
# 95            False 2021-01-01 01:00:00
# 140           False 2021-01-01 02:00:00
# 267           False 2021-01-01 03:00:00
# 360           False 2021-01-01 04:00:00
# ...             ...                 ...
# 3275166       False 2023-12-31 20:00:00
# 3275285       False 2023-12-31 21:00:00
# 3275473       False 2023-12-31 22:00:00
# 3275588       False 2023-12-31 23:00:00
# 3275653       False 2024-01-01 00:00:00
#
# [1598954 rows x 6 columns]

# %% [markdown]
# ## Save to CSV

# %%
output_file = 'metar_dataset_cleaned.csv'
metar_data_final.to_csv(output_file, index=False)
